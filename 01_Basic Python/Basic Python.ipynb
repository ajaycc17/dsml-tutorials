# %% [markdown]
# ## Assignment 1
# ### Due Date: 11 September 2021, Saturday, 11.00 am
# ### Ajay Choudhury (18018) -- BS (2018 batch)

# %% [markdown]
# # Example: weather
# Ask the user what today's weather is
# And then:
# 1. If it's rain or snow -- print something negative
# 2. If it's sun -- print something positive
# 3. If it's neither -- print that you don't know what it is

# %%
weather = input("Enter today's weather: ")
if (weather == 'rain' or weather == 'snow'):
    print("Oh, it must be winter!")
elif weather == 'sunny':
    print("Oh, what a nice day!")
else:
    print("I don't know about " + weather)
# Out:
# Enter today's weather: snow
# Oh, it must be winter!

# %% [markdown]
# # Exercise 1: Name and company
#
# 1. Ask the user for their name, and assign that to `name`.
# 2. Ask the user for their company, and assign that to `company`.
# 3. Print one of four different outputs:
#     - If the name and company match you, say that it must be you!
#     - If neither matches your data, then say something funny (or sarcastic comment).
#     - If the name matches, but not the company, say that their company has a great employee, with a great name
#     - If the company matches, but not the name, say they must be your colleague.

# %%
name = input("Enter your name: ")
name = name.title()

company = input("Your Comapany: ")
company = company.title()

myname = "Ajay"
mycompany = "Random Fate"

if name == myname and company == mycompany:
    print("It must be Ajay")

elif name==myname and company != mycompany:
    print("Your company has a great employee with a great name.")

elif name!=myname and company == mycompany:
    print("You are my colleague for sure.")
    
else:
    print("World is a big place, hope we meet someday.")
# Out:
# Enter your name: ajay
# Your Comapany: random fate
# It must be Ajay

# %% [markdown]
# # Exercise 2: Guessing game
#
# 1. Generate a random number between 0 and 100, and assign that to `number`.
# 2. The number generated by the random module should be guessed by the user.
# 3. Ask the user to enter their guess.
# 4. Print one of three possibilities:
#     - Too high!
#     - Too low!
#     - You got it!
#
# To generate a random number, use the `random` module, a collection of functions for random things.
#
# ```python
# import random
# number = random.randint(0, 100)
# ```

# %%
import random
number = random.randint(0,100)

# take user input until (s)he guesses right or choose to give up
while(True):
    guess = int(input("Your guess (-1 to give up): "))

    # exit condition
    if (guess == -1):
        print("The number was: " + str(number))
        break

    # check user input
    if (guess > number):
        print("Too high!")
    elif (guess < number):
        print("Too low!")
    else:
        print("You got it!")
        break
# Out:
# Your guess (-1 to give up): 5
# Too low!
# Your guess (-1 to give up): 50
# Too low!
# Your guess (-1 to give up): 80
# Too high!
# Your guess (-1 to give up): 70
# Too high!
# Your guess (-1 to give up): 60
# Too high!
# Your guess (-1 to give up): 55
# Too high!
# Your guess (-1 to give up): 52
# You got it!

# %% [markdown]
# # Exercise 3: Pig Latin
#
# Pig Latin is a children's secret language. To translate a word into Pig Latin, follow these rules:
#
# 1. If the first letter is a vowel (a, e, i, o, or u) then add `way` to the end of the word.
# 2. Otherwise, move the first letter to the end of the word, and add `ay`.
#
# Some examples:
#
# - `computer` -> `omputercay`
# - `bhopal` -> `hopalbay`
# - `table` -> `abletay`
# - `apple` -> `appleway`
# - `elephant` -> `elephantway`
# - `iiser` -> `iiserway`
# - `papaya` -> `apayapay`
#
#
# 1. Ask the user to enter a word in English, all lowercase, no punctuation.
# 2. Print the translation of this word into Pig Latin.

# %%
word = input("Your word in lowercase (no punctuation): ")
vowel = ['a', 'e', 'i', 'o', 'u']

if word[:1] in vowel:
    word = word + "way"
else:
    word = word[1:] + word [:1]
    word = word + "ay"
print(word)
# Out:
# Your word in lowercase (no punctuation): random
# andomray

# %% [markdown]
# # Exercise 4: Looping Names
#
#  (1) Ask the user to enter a number (integer).  Ask them to enter
#  their name.  Print their name that number of times.
#
#  Number: 5
#
#  Name: Bhopal
#
# Bhopal
#
# Bhopal
#
# Bhopal
#
# Bhopal
#
# Bhopal
#
# (2) And also ask them to enter their name.  Print a "name triangle"
#
# B
#
# Bh
#
# Bho
#
# Bhop
#
# Bhopa
#
# Bhopal

# %%
# part 1
number = int(input("Enter a number: "))
name = input("Enter your name: ")
name = name.title()

for i in range(number):
    print(name)

# part 2
# we already have user's name
print("\n**** Name Triangle ****")


for i in range(1, len(name)+1):
    print(name[:i])
# Out:
# Enter a number: 5
# Enter your name: ajay choudhury
# Ajay Choudhury
# Ajay Choudhury
# Ajay Choudhury
# Ajay Choudhury
# Ajay Choudhury
#
# **** Name Triangle ****
# A
# Aj
# Aja
# Ajay
# Ajay
# Ajay C
# Ajay Ch
# Ajay Cho
# Ajay Chou
# Ajay Choud
# Ajay Choudh
# Ajay Choudhu
# Ajay Choudhur
# Ajay Choudhury

# %% [markdown]
# # Exercise 5: Restaurant
#
# 1. Define a dict called `menu` in which the keys are the items you can order at the restaurant, and the values are the prices.
# 2. Define `total` to be 0.
# 3. Ask the user, repeatedly, to enter what they want to order.
#     - If they enter an empty string, stop asking and print the total bill.
#     - If they enter an item that *is* on the menu, then print the item, its price, and the new total.
#     - If they enter something that is *not* on the menu, then say that you don't have that.
#
# Example:
#
#     Order: sandwich
#     sandwich is 10, total is 10
#     Order: tea
#     tea is 5, total is 15
#     Order: elephant
#     Sorry, we are fresh out of elephant today!
#     Order: [ENTER]
#     Your total is 15
#
# ### Hints/notes
#
# - Define the `menu` dict at the top with keys and values
# - Use a `while` loop to get the user's input, since we don't know how many we're going to get.
# - Use `in` to check if a key is in the dict

# %%
menu = {'chicken roll': '100', 'butter chicken': '250', 
        'paneer butter masala': '200', 'jeera rice': '50', 
        'pasta': '60'}
total = 0
all_orders = [] # to get all the orders of the user at one place

print("**** MENU ****")
for key in menu:
    print(key)

print("\n**** ORDERS ****")
while(True):
    order = input("Your order (one by one): ")
    order = order.lower()

    if (order == ""):
        print("Your total is: " + str(total))
        # print("\nYour orders are: ")
        # for i in all_orders:
        #     print(i)
        break
    else:
        if(order in menu):
            total = total + int(menu[order])
            print(order + " is " + menu[order] + ", total is " + str(total))
            all_orders.append(order) # appending each order into an array
        else:
            print("Please choose something from menu")
            continue
# Out:
# **** MENU ****
# chicken roll
# butter chicken
# paneer butter masala
# jeera rice
# pasta
#
# **** ORDERS ****
# Your order (one by one): chicken roll
# chicken roll is 100, total is 100
# Your order (one by one): jeera rice
# jeera rice is 50, total is 150
# Your order (one by one): butter chicken
# butter chicken is 250, total is 400
# Your order (one by one):
# Your total is: 400

# %% [markdown]
# # Exercise 6: Rainfall
#
# 1. Define an empty dict, called `rainfall`.  Eventually, its keys will be strings (names of cities) and its values will be integers (mm of rain).
# 2. Ask the user repeatedly to enter the name of a city.
# 3. If they enter an empty string, stop asking and print the dict.
# 4. If we did get a city, then ask the user to enter mm rain that fell in that city.
# 5. Accumulate rainfall for this city in the `rainfall` dict.
#    - If this is the first time we're hearing of this city, then just assign the value.
#    - If this is not the first time, then add to the previous value
# 6. Print the dict
#
# Example:
#
#        City: Bhopal
#        Rain: 2
#        City: Chennai
#        Rain: 4
#        City: Bhopal
#        Rain: 3
#        City: [ENTER]
#        {'Bhopal':5, 'Chennai':4}

# %%
rainfall = {}
while(True):
    city = input("City: ")
    city = city.title()

    if (city == ""):
        # # printing the dictionary
        # for key,value in rainfall.items():
        #     print(key + ": " + str(value) + "mm")
        print(rainfall)
        break

    rain = input("Rainfall in " + city + " (in mm): ")
    # user must provide rainfall
    while(True):
        if rain == "":
            rain = input("Rainfall in " + city + " (in mm): ")
        else:
            rain = int(rain)
            break

    # if city exists add the new rainfall amount to the previous rainfall amount
    if city in rainfall:            
        rainfall[city] += rain
    else:
        rainfall[city] = rain
# Out:
# City: bhopal
# Rainfall in Bhopal (in mm): 130
# City: kolkata
# Rainfall in Kolkata (in mm): 160
# City: bhopal
# Rainfall in Bhopal (in mm): 200
# City: bhopal
# Rainfall in Bhopal (in mm): 300
# City: bhopal
# Rainfall in Bhopal (in mm): 500
# City:
# {'Bhopal': 1130, 'Kolkata': 160}

# %% [markdown]
# # Exercise 7: Simple calculator
#
# 1. Define a function, `calc`.
# 2. In the body of the function:
#     - Ask the user to enter a number, and assign it to x.
#     - Ask the user to enter a second number, and assign it to y.
#     - Ask the user to enter an operator (`+` or `-`), and assign it to `op`
# 3. Return the result of either adding or subtracting the two numbers.
# 4. If the user entered a non-number or an operator that we don't recognize, you can return a string with an error... but that's not really the point here.
#
# ### Exercise: calc, revisited
#
# Rewrite our `calc` function so that it does *not* use `input` to get the numbers and their operator. Rather, these should be passed as *three* separate arguments, to be placed in parameters `first`, `second`, and `op`.
#
# ```python
# print(calc(5, 10, '+'))
# print(calc(35, 18, '-'))
#
# ```

# %%
# # taking user input

# def calc():
#     x = input("Enter first number: ")
#     y = input("Enter second number: ")
#     op = input("Enter an operator(+ or -): ")

#     if(x.isnumeric() and y.isnumeric()):
#         x = float(x)
#         y = float(y)
#         if(op == "+"):
#             return x+y
#         elif(op == "-"):
#             return x-y
#         else:
#             print("We do not recognise the operator currently!")

#     else:
#         print("Error! We cannot operate on strings!")

# **************** revisited *******************

# using parameters

def calc(first, second, op):
    if(isinstance(first, int) or isinstance(first, float)  and isinstance(second, int) or isinstance(second, float)):
        if(op == "+"):
            return first+second
        elif(op == "-"):
            return first-second
        else:
            print(f"We do not recognise the operator '{op}' currently!")

    else:
        print("Error! We cannot operate on strings!")

if __name__ == "__main__":
    print(calc(35.23, 20, "+"))
# Out:
# 55.23

# %% [markdown]
# # Exercise 8: Biggest and smallest
#
# 1. Write a function, `biggest_and_smallest`, that takes a list of numbers.
# 2. The result from the function will be a two-element tuple containing the smallest number in the input list and the largest number in the input list.
# 3. Do *not* use any built-in Python functions for sorting, including `min` and `max`.
# 4. wouldn't it be nice if we could pass our numbers to the function *without* using a list? For this, we have *args
#
# Example:
#
#     biggest_and_smallest([53, 22, 97, 102, 15, 17, 12])
#
# That will return the tuple
#
#     (12, 102)
#
# Hints:
#
# - You're going to have to go through each element of the list
# - Is it bigger than the biggest thing you've seen so far?  Or is it smaller than the smallest thing you've seen so far?

# %%
def biggest_and_smallest(*args):
    min = args[0]
    max = args[0]

    for i in args:
        if i<min:
            min = i
        if i>max:
            max = i
    min_max = (min, max)  # tuple of (minimum, maximum)
    return min_max

# function call
tuple = biggest_and_smallest(513, 2200, 97, 102, 15, 17, 102)
print(tuple)
# Out:
# (15, 2200)
